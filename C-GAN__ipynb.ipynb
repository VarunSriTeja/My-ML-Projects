# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
from tensorflow.keras import layers
import time
import matplotlib.pyplot as plt
import os


BATCH_SIZE = 32
noise_dim = 100
EPOCHS = 2000
num_examples_to_generate = 16
CHECKPOINT_DIR = './training_checkpoints'


datagen = ImageDataGenerator(rescale=1.0/255.0)

dataset = datagen.flow_from_directory('/content/drive/MyDrive/horse-or-human',
                                      target_size=(64, 64),
                                      batch_size=BATCH_SIZE,
                                      class_mode=None,
                                      shuffle=True)


def build_generator():
    model = tf.keras.Sequential()
    model.add(layers.Dense(8*8*256, use_bias=False, input_shape=(noise_dim,)))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())
    model.add(layers.Reshape((8, 8, 256)))
    model.add(layers.Conv2DTranspose(128, (5, 5), strides=(2, 2), padding='same', use_bias=False))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())
    model.add(layers.Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same', use_bias=False))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())
    model.add(layers.Conv2DTranspose(3, (5, 5), strides=(2, 2), padding='same', use_bias=False, activation='tanh'))
    return model

generator = build_generator()

def build_discriminator():
    model = tf.keras.Sequential()
    model.add(layers.Conv2D(64, (5, 5), strides=(2, 2), padding='same', input_shape=[64, 64, 3]))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))
    model.add(layers.Conv2D(128, (5, 5), strides=(2, 2), padding='same'))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))
    model.add(layers.Flatten())
    model.add(layers.Dense(1))
    return model

discriminator = build_discriminator()

cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

@tf.function
def train_step(images):
    noise = tf.random.normal([BATCH_SIZE, noise_dim])
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_images = generator(noise, training=True)
        real_output = discriminator(images, training=True)
        fake_output = discriminator(generated_images, training=True)
        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)
        print(gen_loss)
        print(disc_loss)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

def generate_and_save_images(model, epoch, test_input):
    predictions = model(test_input, training=False)
    fig = plt.figure(figsize=(4, 4))
    for i in range(predictions.shape[0]):
        plt.subplot(4, 4, i + 1)
        plt.imshow((predictions[i] * 0.5 + 0.5).numpy())
        plt.axis('off')
    plt.savefig(f'image_at_epoch_{epoch:04d}.png')
    plt.close(fig)

seed = tf.random.normal([num_examples_to_generate, noise_dim])

images = []
for _ in range(len(dataset)):
    batch = next(dataset)
    images.append(batch)

images = np.concatenate(images, axis=0)
images = images.astype('float32')
images = (images - 0.5) / 0.5
train_dataset = tf.data.Dataset.from_tensor_slices(images).shuffle(60000).batch(BATCH_SIZE)

checkpoint_prefix = os.path.join(CHECKPOINT_DIR, "ckpt")
checkpoint = tf.train.Checkpoint(generator=generator,
                                 discriminator=discriminator,
                                 generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer)

def train(dataset, epochs, start_epoch=0):
    for epoch in range(start_epoch, epochs):
        start = time.time()
        for image_batch in dataset:
            train_step(image_batch)
        generate_and_save_images(generator, epoch + 1, seed)
        print(f'Time for epoch {epoch + 1} is {time.time() - start} sec')
        checkpoint.save(file_prefix=checkpoint_prefix)
    generate_and_save_images(generator, epochs, seed)

if not os.path.exists(CHECKPOINT_DIR):
    os.makedirs(CHECKPOINT_DIR)
    start_epoch = 0
else:
    start_epoch = 0

train(train_dataset, EPOCHS, start_epoch)
# Out:
# Found 1027 images belonging to 2 classes.
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Tensor("binary_crossentropy/truediv:0", shape=(), dtype=float32)
# Tensor("add:0", shape=(), dtype=float32)
# Tensor("binary_crossentropy/truediv:0", shape=(), dtype=float32)
# Tensor("add:0", shape=(), dtype=float32)
# Tensor("binary_crossentropy/truediv:0", shape=(), dtype=float32)
# Tensor("add:0", shape=(), dtype=float32)
# Time for epoch 1 is 12.08403992652893 sec
# Time for epoch 2 is 1.2366952896118164 sec
# Time for epoch 3 is 1.238903284072876 sec
# Time for epoch 4 is 1.2317898273468018 sec
# Time for epoch 5 is 1.2240736484527588 sec
# Time for epoch 6 is 1.6654422283172607 sec
# Time for epoch 7 is 1.4312033653259277 sec
# Time for epoch 8 is 1.2235941886901855 sec
# Time for epoch 9 is 1.234706163406372 sec
# Time for epoch 10 is 1.2278430461883545 sec
# Time for epoch 11 is 1.5418109893798828 sec
# Time for epoch 12 is 1.2356171607971191 sec
# Time for epoch 13 is 1.2382020950317383 sec
# Time for epoch 14 is 1.2508325576782227 sec
# Time for epoch 15 is 1.3808927536010742 sec
# Time for epoch 16 is 1.4254717826843262 sec
# Time for epoch 17 is 1.234722375869751 sec
# Time for epoch 18 is 1.5864014625549316 sec
# Time for epoch 19 is 1.2618403434753418 sec
# Time for epoch 20 is 1.2651746273040771 sec
# Time for epoch 21 is 1.2483127117156982 sec
# Time for epoch 22 is 1.2387158870697021 sec
# Time for epoch 23 is 1.2531001567840576 sec
# Time for epoch 24 is 1.3922138214111328 sec
# Time for epoch 25 is 1.4119279384613037 sec
# Time for epoch 26 is 1.2563841342926025 sec
# Time for epoch 27 is 1.6999423503875732 sec
# Time for epoch 28 is 1.2625486850738525 sec
# Time for epoch 29 is 1.2595386505126953 sec
# Time for epoch 30 is 1.2458372116088867 sec
# Time for epoch 31 is 1.2718443870544434 sec
# Time for epoch 32 is 1.2694861888885498 sec
# Time for epoch 33 is 1.4049184322357178 sec
# Time for epoch 34 is 1.4530627727508545 sec
# Time for epoch 35 is 1.28670072555542 sec
# Time for epoch 36 is 1.3165338039398193 sec
# Time for epoch 37 is 1.2558369636535645 sec
# Time for epoch 38 is 1.825676441192627 sec
# Time for epoch 39 is 1.2701876163482666 sec
# Time for epoch 40 is 1.2492783069610596 sec
# Time for epoch 41 is 1.2721362113952637 sec
# Time for epoch 42 is 1.4285764694213867 sec
# Time for epoch 43 is 1.4463725090026855 sec
# Time for epoch 44 is 1.2732112407684326 sec
# Time for epoch 45 is 1.2678320407867432 sec
# Time for epoch 46 is 1.283325433731079 sec
# Time for epoch 47 is 1.2620837688446045 sec
# Time for epoch 48 is 1.2679829597473145 sec
# Time for epoch 49 is 1.2904274463653564 sec
# Time for epoch 50 is 1.276181697845459 sec
# Time for epoch 51 is 2.255577325820923 sec
# Time for epoch 52 is 1.4445335865020752 sec
# Time for epoch 53 is 1.2824628353118896 sec
# Time for epoch 54 is 1.2849395275115967 sec
# Time for epoch 55 is 1.2815978527069092 sec
# Time for epoch 56 is 1.2674922943115234 sec
# Time for epoch 57 is 1.2977685928344727 sec
# Time for epoch 58 is 1.2768864631652832 sec
# Time for epoch 59 is 1.317314863204956 sec
# Time for epoch 60 is 1.475156545639038 sec
# Time for epoch 61 is 1.5444533824920654 sec
# Time for epoch 62 is 1.2824599742889404 sec
# Time for epoch 63 is 1.2829973697662354 sec
# Time for epoch 64 is 1.27225661277771 sec
# Time for epoch 65 is 1.2757081985473633 sec
# Time for epoch 66 is 1.2834680080413818 sec
# Time for epoch 67 is 2.1049766540527344 sec
# Time for epoch 68 is 1.4110832214355469 sec
# Time for epoch 69 is 1.4336347579956055 sec
# Time for epoch 70 is 1.3185255527496338 sec
# Time for epoch 71 is 1.2593834400177002 sec
# Time for epoch 72 is 1.262430191040039 sec
# Time for epoch 73 is 1.2664060592651367 sec
# Time for epoch 74 is 1.2780046463012695 sec
# Time for epoch 75 is 1.2577617168426514 sec
# Time for epoch 76 is 1.2530980110168457 sec
# Time for epoch 77 is 1.4186906814575195 sec
# Time for epoch 78 is 1.4028704166412354 sec
# Time for epoch 79 is 1.299645185470581 sec
# Time for epoch 80 is 1.2506532669067383 sec
# Time for epoch 81 is 1.277921199798584 sec
# Time for epoch 82 is 1.2618093490600586 sec
# Time for epoch 83 is 1.2544529438018799 sec
# Time for epoch 84 is 1.2833220958709717 sec
# Time for epoch 85 is 1.2728030681610107 sec
# Time for epoch 86 is 1.3140668869018555 sec
# Time for epoch 87 is 1.4049324989318848 sec
# Time for epoch 88 is 2.4494853019714355 sec
# Time for epoch 89 is 1.2728745937347412 sec
# Time for epoch 90 is 1.2602477073669434 sec
# Time for epoch 91 is 1.260796308517456 sec
# Time for epoch 92 is 1.2757270336151123 sec
# Time for epoch 93 is 1.2716240882873535 sec
# Time for epoch 94 is 1.2626757621765137 sec
# Time for epoch 95 is 1.3994767665863037 sec
# Time for epoch 96 is 1.469452142715454 sec
# Time for epoch 97 is 1.2742855548858643 sec
# Time for epoch 98 is 1.2549445629119873 sec
# Time for epoch 99 is 1.2755446434020996 sec
# Time for epoch 100 is 1.2811830043792725 sec
# Time for epoch 101 is 1.2819759845733643 sec
# Time for epoch 102 is 1.2625834941864014 sec
# Time for epoch 103 is 1.2546017169952393 sec
# Time for epoch 104 is 1.4157369136810303 sec
# Time for epoch 105 is 1.430238962173462 sec
# Time for epoch 106 is 1.2774441242218018 sec
# Time for epoch 107 is 1.2565808296203613 sec
# Time for epoch 108 is 1.2826285362243652 sec
# Time for epoch 109 is 1.2576725482940674 sec
# Time for epoch 110 is 1.267064094543457 sec
# Time for epoch 111 is 1.2749733924865723 sec
# Time for epoch 112 is 1.2678420543670654 sec
# Time for epoch 113 is 3.034156084060669 sec
# Time for epoch 114 is 1.375260353088379 sec
# Time for epoch 115 is 1.2706379890441895 sec
# Time for epoch 116 is 1.26408052444458 sec
# Time for epoch 117 is 1.2836384773254395 sec
# Time for epoch 118 is 1.267721176147461 sec
# Time for epoch 119 is 1.2832281589508057 sec
# Time for epoch 120 is 1.2834968566894531 sec
# Time for epoch 121 is 1.3405437469482422 sec
# Time for epoch 122 is 1.4341118335723877 sec
# Time for epoch 123 is 1.4077839851379395 sec
# Time for epoch 124 is 1.2798118591308594 sec
# Time for epoch 125 is 1.2668194770812988 sec
# Time for epoch 126 is 1.3119337558746338 sec
# Time for epoch 127 is 1.27769136428833 sec
# Time for epoch 128 is 1.2631022930145264 sec
# Time for epoch 129 is 1.2930703163146973 sec
# Time for epoch 130 is 1.269516944885254 sec
# Time for epoch 131 is 1.408837080001831 sec
# Time for epoch 132 is 1.45918869972229 sec
# Time for epoch 133 is 1.3234655857086182 sec
# Time for epoch 134 is 1.2690105438232422 sec
# Time for epoch 135 is 1.2729675769805908 sec
# Time for epoch 136 is 1.2742853164672852 sec
# Time for epoch 137 is 1.2690658569335938 sec
# Time for epoch 138 is 1.2535967826843262 sec
# Time for epoch 139 is 1.2694993019104004 sec
# Time for epoch 140 is 1.4298064708709717 sec
# Time for epoch 141 is 1.445512056350708 sec
# Time for epoch 142 is 1.267317295074463 sec
# Time for epoch 143 is 1.2751288414001465 sec
# Time for epoch 144 is 1.2722225189208984 sec
# Time for epoch 145 is 2.85514760017395 sec
# Time for epoch 146 is 1.3672871589660645 sec
# Time for epoch 147 is 1.275604248046875 sec
# Time for epoch 148 is 1.388850450515747 sec
# Time for epoch 149 is 1.4379639625549316 sec
# Time for epoch 150 is 1.2524464130401611 sec
# Time for epoch 151 is 1.263242244720459 sec
# Time for epoch 152 is 1.253981351852417 sec
# Time for epoch 153 is 1.268932580947876 sec
# Time for epoch 154 is 1.2840032577514648 sec
# Time for epoch 155 is 1.2668566703796387 sec
# Time for epoch 156 is 1.257601261138916 sec
# Time for epoch 157 is 1.4158110618591309 sec
# Time for epoch 158 is 1.4121694564819336 sec
# Time for epoch 159 is 1.2999765872955322 sec
# Time for epoch 160 is 1.2678077220916748 sec
# Time for epoch 161 is 1.287086009979248 sec
# Time for epoch 162 is 1.2643423080444336 sec
# Time for epoch 163 is 1.2596631050109863 sec
# Time for epoch 164 is 1.272768259048462 sec
# Time for epoch 165 is 1.2766363620758057 sec
# Time for epoch 166 is 1.3890800476074219 sec
# Time for epoch 167 is 1.425696849822998 sec
# Time for epoch 168 is 1.3710715770721436 sec
# Time for epoch 169 is 1.271735668182373 sec
# Time for epoch 170 is 1.2592520713806152 sec
# Time for epoch 171 is 1.2692861557006836 sec
# Time for epoch 172 is 1.2655696868896484 sec
# Time for epoch 173 is 1.2724900245666504 sec
# Time for epoch 174 is 1.2843098640441895 sec
# Time for epoch 175 is 1.2595186233520508 sec
# Time for epoch 176 is 1.446265697479248 sec
# Time for epoch 177 is 1.47308349609375 sec
# Time for epoch 178 is 1.2692265510559082 sec
# Time for epoch 179 is 1.2662010192871094 sec
# Time for epoch 180 is 1.2666161060333252 sec
# Time for epoch 181 is 1.2693991661071777 sec
# Time for epoch 182 is 1.2555210590362549 sec
# Time for epoch 183 is 1.2640776634216309 sec
# Time for epoch 184 is 1.2671799659729004 sec
# Time for epoch 185 is 3.994553804397583 sec
# Time for epoch 186 is 1.3676280975341797 sec
# Time for epoch 187 is 1.2640724182128906 sec
# Time for epoch 188 is 1.2642571926116943 sec
# Time for epoch 189 is 1.2571079730987549 sec
# Time for epoch 190 is 1.2708978652954102 sec
# Time for epoch 191 is 1.271435022354126 sec
# Time for epoch 192 is 1.2605292797088623 sec
# Time for epoch 193 is 1.4952616691589355 sec
# Time for epoch 194 is 1.4461493492126465 sec
# Time for epoch 195 is 1.2703311443328857 sec
# Time for epoch 196 is 1.2722234725952148 sec
# Time for epoch 197 is 1.2763500213623047 sec
# Time for epoch 198 is 1.2538814544677734 sec
# Time for epoch 199 is 1.271761178970337 sec
# Time for epoch 200 is 1.2887852191925049 sec
# Time for epoch 201 is 1.2660613059997559 sec
# Time for epoch 202 is 1.4221875667572021 sec
# Time for epoch 203 is 1.433441400527954 sec
# Time for epoch 204 is 1.2987473011016846 sec
# Time for epoch 205 is 1.2728443145751953 sec
# Time for epoch 206 is 1.269235610961914 sec
# Time for epoch 207 is 1.2723283767700195 sec
# Time for epoch 208 is 1.2764720916748047 sec
# Time for epoch 209 is 1.2599592208862305 sec
# Time for epoch 210 is 1.2793898582458496 sec
# Time for epoch 211 is 1.4181020259857178 sec
# Time for epoch 212 is 1.4285590648651123 sec
# Time for epoch 213 is 1.3591203689575195 sec
# Time for epoch 214 is 1.2868797779083252 sec
# Time for epoch 215 is 1.2678894996643066 sec
# Time for epoch 216 is 1.2844889163970947 sec
# Time for epoch 217 is 1.2597944736480713 sec
# Time for epoch 218 is 1.2656292915344238 sec
# Time for epoch 219 is 1.2833619117736816 sec
# Time for epoch 220 is 1.278198003768921 sec
# Time for epoch 221 is 1.4159817695617676 sec
# Time for epoch 222 is 1.4764442443847656 sec
# Time for epoch 223 is 1.2721784114837646 sec
# Time for epoch 224 is 1.2567706108093262 sec
# Time for epoch 225 is 1.2628800868988037 sec
# Time for epoch 226 is 1.2648227214813232 sec
# Time for epoch 227 is 1.2700896263122559 sec
# Time for epoch 228 is 1.26180100440979 sec
# Time for epoch 229 is 1.2673823833465576 sec
# Time for epoch 230 is 1.3960635662078857 sec
# Time for epoch 231 is 1.4539058208465576 sec
# Time for epoch 232 is 1.261120319366455 sec
# Time for epoch 233 is 1.2705016136169434 sec
# Time for epoch 234 is 3.7556986808776855 sec
# Time for epoch 235 is 1.3622770309448242 sec
# Time for epoch 236 is 1.2569801807403564 sec
# Time for epoch 237 is 1.3643279075622559 sec
# Time for epoch 238 is 1.415848970413208 sec
# Time for epoch 239 is 1.4686040878295898 sec
# Time for epoch 240 is 1.262378215789795 sec
# Time for epoch 241 is 1.2720880508422852 sec
# Time for epoch 242 is 1.261789083480835 sec
# Time for epoch 243 is 1.2568390369415283 sec
# Time for epoch 244 is 1.274735450744629 sec
# Time for epoch 245 is 1.3036997318267822 sec
# Time for epoch 246 is 1.2816579341888428 sec
# Time for epoch 247 is 1.4139060974121094 sec
# Time for epoch 248 is 1.4682343006134033 sec
# Time for epoch 249 is 1.2675037384033203 sec
# Time for epoch 250 is 1.263174057006836 sec
# Time for epoch 251 is 1.2722456455230713 sec
# Time for epoch 252 is 1.272275447845459 sec
# Time for epoch 253 is 1.2837395668029785 sec
# Time for epoch 254 is 1.258070945739746 sec
# Time for epoch 255 is 1.2632782459259033 sec
# Time for epoch 256 is 1.438918113708496 sec
# Time for epoch 257 is 1.4431450366973877 sec
# Time for epoch 258 is 1.265712022781372 sec
# Time for epoch 259 is 1.2649810314178467 sec
# Time for epoch 260 is 1.2891545295715332 sec
# Time for epoch 261 is 1.2697503566741943 sec
# Time for epoch 262 is 1.2649414539337158 sec
# Time for epoch 263 is 1.2786791324615479 sec
# Time for epoch 264 is 1.296370029449463 sec
# Time for epoch 265 is 1.4173049926757812 sec
# Time for epoch 266 is 1.404341697692871 sec
# Time for epoch 267 is 1.276928424835205 sec
# Time for epoch 268 is 1.261073112487793 sec
# Time for epoch 269 is 1.264390468597412 sec
# Time for epoch 270 is 1.2765421867370605 sec
# Time for epoch 271 is 1.2648987770080566 sec
# Time for epoch 272 is 1.2512133121490479 sec
# Time for epoch 273 is 1.2670559883117676 sec
# Time for epoch 274 is 1.3184711933135986 sec
# Time for epoch 275 is 1.434997797012329 sec
# Time for epoch 276 is 1.491119384765625 sec
# Time for epoch 277 is 1.2756175994873047 sec
# Time for epoch 278 is 1.2684001922607422 sec
# Time for epoch 279 is 1.2578608989715576 sec
# Time for epoch 280 is 1.2710254192352295 sec
# Time for epoch 281 is 1.2539303302764893 sec
# Time for epoch 282 is 1.2678840160369873 sec
# Time for epoch 283 is 1.2635688781738281 sec
# Time for epoch 284 is 1.4198317527770996 sec
# Time for epoch 285 is 1.4516758918762207 sec
# Time for epoch 286 is 1.3017315864562988 sec
# Time for epoch 287 is 1.2753422260284424 sec
# Time for epoch 288 is 1.255805253982544 sec
# Time for epoch 289 is 1.2730967998504639 sec
# Time for epoch 290 is 1.2706639766693115 sec
# Time for epoch 291 is 1.2689473628997803 sec
# Time for epoch 292 is 1.2819058895111084 sec
# Time for epoch 293 is 1.4011545181274414 sec
# Time for epoch 294 is 1.4305379390716553 sec
# Time for epoch 295 is 1.2718312740325928 sec
# Time for epoch 296 is 4.375565052032471 sec
# Time for epoch 297 is 1.3286118507385254 sec
# Time for epoch 298 is 1.2594447135925293 sec
# Time for epoch 299 is 1.2667231559753418 sec
# Time for epoch 300 is 1.4273858070373535 sec
# Time for epoch 301 is 1.4073078632354736 sec
# Time for epoch 302 is 1.3191983699798584 sec
# Time for epoch 303 is 1.2510428428649902 sec
# Time for epoch 304 is 1.2716002464294434 sec
# Time for epoch 305 is 1.270555019378662 sec
# Time for epoch 306 is 1.2776811122894287 sec
# Time for epoch 307 is 1.2760155200958252 sec
# Time for epoch 308 is 1.2614169120788574 sec
# Time for epoch 309 is 1.3652818202972412 sec
# Time for epoch 310 is 1.4061470031738281 sec
# Time for epoch 311 is 1.4699504375457764 sec
# Time for epoch 312 is 1.264434576034546 sec
# Time for epoch 313 is 1.270655870437622 sec
# Time for epoch 314 is 1.2665669918060303 sec
# Time for epoch 315 is 1.2664539813995361 sec
# Time for epoch 316 is 1.2905335426330566 sec
# Time for epoch 317 is 1.2658333778381348 sec
# Time for epoch 318 is 1.280569076538086 sec
# Time for epoch 319 is 1.7402081489562988 sec
# Time for epoch 320 is 1.407975673675537 sec
# Time for epoch 321 is 1.2618703842163086 sec
# Time for epoch 322 is 1.269874095916748 sec
# Time for epoch 323 is 1.2647480964660645 sec
# Time for epoch 324 is 1.2559731006622314 sec
# Time for epoch 325 is 1.274573802947998 sec
# Time for epoch 326 is 1.2587976455688477 sec
# Time for epoch 327 is 1.2691876888275146 sec
# Time for epoch 328 is 1.4126319885253906 sec
# Time for epoch 329 is 1.4578883647918701 sec
# Time for epoch 330 is 1.2883074283599854 sec
# Time for epoch 331 is 1.2632346153259277 sec
# Time for epoch 332 is 1.2767534255981445 sec
# Time for epoch 333 is 1.2636544704437256 sec
# Time for epoch 334 is 1.2635853290557861 sec
# Time for epoch 335 is 1.2566511631011963 sec
# Time for epoch 336 is 1.2706005573272705 sec
# Time for epoch 337 is 1.4299015998840332 sec
# Time for epoch 338 is 1.4333202838897705 sec
# Time for epoch 339 is 1.2702305316925049 sec
# Time for epoch 340 is 1.265791416168213 sec
# Time for epoch 341 is 1.2735464572906494 sec
# Time for epoch 342 is 1.2620360851287842 sec
# Time for epoch 343 is 1.2864243984222412 sec
# Time for epoch 344 is 1.2649435997009277 sec
# Time for epoch 345 is 1.2590694427490234 sec
# Time for epoch 346 is 1.3015244007110596 sec
# Time for epoch 347 is 1.4247169494628906 sec
# Time for epoch 348 is 1.4387807846069336 sec
# Time for epoch 349 is 1.2866013050079346 sec
# Time for epoch 350 is 1.2657294273376465 sec
# Time for epoch 351 is 1.2674973011016846 sec
# Time for epoch 352 is 1.2575116157531738 sec
# Time for epoch 353 is 1.267754316329956 sec
# Time for epoch 354 is 1.270094394683838 sec
# Time for epoch 355 is 1.2674436569213867 sec
# Time for epoch 356 is 1.412168264389038 sec
# Time for epoch 357 is 1.4482183456420898 sec
# Time for epoch 358 is 1.278458833694458 sec
# Time for epoch 359 is 1.2488162517547607 sec
# Time for epoch 360 is 1.2809820175170898 sec
# Time for epoch 361 is 1.2709214687347412 sec
# Time for epoch 362 is 1.2624592781066895 sec
# Time for epoch 363 is 1.2656276226043701 sec
# Time for epoch 364 is 1.262481927871704 sec
# Time for epoch 365 is 1.3607022762298584 sec
# Time for epoch 366 is 1.4182090759277344 sec
# Time for epoch 367 is 1.4923596382141113 sec
# Time for epoch 368 is 1.264387607574463 sec
# Time for epoch 369 is 1.2665777206420898 sec
# Time for epoch 370 is 1.2602434158325195 sec
# Time for epoch 371 is 1.260873794555664 sec
# Time for epoch 372 is 1.2745492458343506 sec
# Time for epoch 373 is 5.610950469970703 sec
# Time for epoch 374 is 1.3557660579681396 sec
# Time for epoch 375 is 1.2734899520874023 sec
# Time for epoch 376 is 1.2527787685394287 sec
# Time for epoch 377 is 1.2606611251831055 sec
# Time for epoch 378 is 1.3307373523712158 sec
# Time for epoch 379 is 1.2634124755859375 sec
# Time for epoch 380 is 1.2657921314239502 sec
# Time for epoch 381 is 1.7261745929718018 sec
# Time for epoch 382 is 1.4459748268127441 sec
# Time for epoch 383 is 1.2736430168151855 sec
# Time for epoch 384 is 1.2698099613189697 sec
# Time for epoch 385 is 1.259840965270996 sec
# Time for epoch 386 is 1.2669951915740967 sec
# Time for epoch 387 is 1.285287857055664 sec
# Time for epoch 388 is 1.2737936973571777 sec
# Time for epoch 389 is 1.2592082023620605 sec
# Time for epoch 390 is 1.4368419647216797 sec
# Time for epoch 391 is 1.416898488998413 sec
# Time for epoch 392 is 1.4529740810394287 sec
# Time for epoch 393 is 1.2819273471832275 sec
# Time for epoch 394 is 1.2840797901153564 sec
# Time for epoch 395 is 1.264754056930542 sec
# Time for epoch 396 is 1.2831270694732666 sec
# Time for epoch 397 is 1.2812774181365967 sec
# Time for epoch 398 is 1.28364896774292 sec
# Time for epoch 399 is 1.2795541286468506 sec
# Time for epoch 400 is 1.4377009868621826 sec
# Time for epoch 401 is 1.4433925151824951 sec
# Time for epoch 402 is 1.2701117992401123 sec
# Time for epoch 403 is 1.2763822078704834 sec
# Time for epoch 404 is 1.2715167999267578 sec
# Time for epoch 405 is 1.2617664337158203 sec
# Time for epoch 406 is 1.2858612537384033 sec
# Time for epoch 407 is 1.2746806144714355 sec
# Time for epoch 408 is 1.2585926055908203 sec
# Time for epoch 409 is 1.7435188293457031 sec
# Time for epoch 410 is 1.4637079238891602 sec
# Time for epoch 411 is 1.2841823101043701 sec
# Time for epoch 412 is 1.275632619857788 sec
# Time for epoch 413 is 1.2643728256225586 sec
# Time for epoch 414 is 1.2601487636566162 sec
# Time for epoch 415 is 1.2760744094848633 sec
# Time for epoch 416 is 1.2566514015197754 sec
# Time for epoch 417 is 1.2984237670898438 sec
# Time for epoch 418 is 1.740701675415039 sec
# Time for epoch 419 is 1.4938058853149414 sec
# Time for epoch 420 is 1.277864933013916 sec
# Time for epoch 421 is 1.2703938484191895 sec
# Time for epoch 422 is 1.2615149021148682 sec
# Time for epoch 423 is 1.2738404273986816 sec
# Time for epoch 424 is 1.2586510181427002 sec
# Time for epoch 425 is 1.2641637325286865 sec
# Time for epoch 426 is 1.2796149253845215 sec
# Time for epoch 427 is 1.404670000076294 sec
# Time for epoch 428 is 1.4481616020202637 sec
# Time for epoch 429 is 1.4049439430236816 sec
# Time for epoch 430 is 1.2600936889648438 sec
# Time for epoch 431 is 1.2710537910461426 sec
# Time for epoch 432 is 1.2962777614593506 sec
# Time for epoch 433 is 1.274637222290039 sec
# Time for epoch 434 is 1.281348705291748 sec
# Time for epoch 435 is 1.2568058967590332 sec
# Time for epoch 436 is 1.289907455444336 sec
# Time for epoch 437 is 1.41678786277771 sec
# Time for epoch 438 is 1.492316722869873 sec
# Time for epoch 439 is 1.254399061203003 sec
# Time for epoch 440 is 1.2699508666992188 sec
# Time for epoch 441 is 1.306384801864624 sec
# Time for epoch 442 is 1.2777082920074463 sec
# Time for epoch 443 is 1.2757253646850586 sec
# Time for epoch 444 is 1.2759292125701904 sec
# Time for epoch 445 is 1.2856569290161133 sec
# Time for epoch 446 is 1.3934192657470703 sec
# Time for epoch 447 is 1.461456537246704 sec
# Time for epoch 448 is 1.3022253513336182 sec
# Time for epoch 449 is 1.2747342586517334 sec
# Time for epoch 450 is 1.2572548389434814 sec
# Time for epoch 451 is 1.267277479171753 sec
# Time for epoch 452 is 1.2705378532409668 sec
# Time for epoch 453 is 1.2681808471679688 sec
# Time for epoch 454 is 1.2688617706298828 sec
# Time for epoch 455 is 1.4131383895874023 sec
# Time for epoch 456 is 1.4051692485809326 sec
# Time for epoch 457 is 1.5462555885314941 sec
# Time for epoch 458 is 1.297222375869751 sec
# Time for epoch 459 is 1.2707273960113525 sec
# Time for epoch 460 is 1.3263885974884033 sec
# Time for epoch 461 is 1.2758708000183105 sec
# Time for epoch 462 is 1.277949571609497 sec
# Time for epoch 463 is 1.2581970691680908 sec
# Time for epoch 464 is 1.275285243988037 sec
# Time for epoch 465 is 1.4515655040740967 sec
# Time for epoch 466 is 1.4792802333831787 sec
# Time for epoch 467 is 1.2749965190887451 sec
# Time for epoch 468 is 6.104585409164429 sec
# Time for epoch 469 is 1.326106071472168 sec
# Time for epoch 470 is 1.2637090682983398 sec
# Time for epoch 471 is 1.4271185398101807 sec
# Time for epoch 472 is 1.443591594696045 sec
# Time for epoch 473 is 1.2890853881835938 sec
# Time for epoch 474 is 1.2641127109527588 sec
# Time for epoch 475 is 1.2615678310394287 sec
# Time for epoch 476 is 1.2681825160980225 sec
# Time for epoch 477 is 1.2624986171722412 sec
# Time for epoch 478 is 1.2740387916564941 sec
# Time for epoch 479 is 1.2813897132873535 sec
# Time for epoch 480 is 1.4060313701629639 sec
# Time for epoch 481 is 1.4282944202423096 sec
# Time for epoch 482 is 1.442383050918579 sec
# Time for epoch 483 is 1.2705278396606445 sec
# Time for epoch 484 is 1.2749788761138916 sec
# Time for epoch 485 is 1.2875316143035889 sec
# Time for epoch 486 is 1.2714273929595947 sec
# Time for epoch 487 is 1.2706248760223389 sec
# Time for epoch 488 is 1.2913901805877686 sec
# Time for epoch 489 is 1.2879414558410645 sec
# Time for epoch 490 is 1.4246134757995605 sec
# Time for epoch 491 is 1.5174415111541748 sec
# Time for epoch 492 is 1.271780252456665 sec
# Time for epoch 493 is 1.2736282348632812 sec
# Time for epoch 494 is 1.2821245193481445 sec
# Time for epoch 495 is 1.2767763137817383 sec
# Time for epoch 496 is 1.2980453968048096 sec
# Time for epoch 497 is 1.303492546081543 sec
# Time for epoch 498 is 1.269073724746704 sec
# Time for epoch 499 is 1.4277007579803467 sec
# Time for epoch 500 is 1.4783968925476074 sec
# Time for epoch 501 is 1.2690327167510986 sec
# Time for epoch 502 is 1.3134527206420898 sec
# Time for epoch 503 is 1.257767677307129 sec
# Time for epoch 504 is 1.2803902626037598 sec
# Time for epoch 505 is 1.2550570964813232 sec
# Time for epoch 506 is 1.255690336227417 sec
# Time for epoch 507 is 1.2876667976379395 sec
# Time for epoch 508 is 1.3832142353057861 sec
# Time for epoch 509 is 1.430295705795288 sec
# Time for epoch 510 is 1.5010344982147217 sec
# Time for epoch 511 is 1.257824182510376 sec
# Time for epoch 512 is 1.2643375396728516 sec
# Time for epoch 513 is 1.2730205059051514 sec
# Time for epoch 514 is 1.2606391906738281 sec
# Time for epoch 515 is 1.268329381942749 sec
# Time for epoch 516 is 1.2700283527374268 sec
# Time for epoch 517 is 1.2695815563201904 sec
# Time for epoch 518 is 1.4725468158721924 sec
# Time for epoch 519 is 1.431187391281128 sec
# Time for epoch 520 is 1.297677755355835 sec
# Time for epoch 521 is 1.2615525722503662 sec
# Time for epoch 522 is 1.2627909183502197 sec
# Time for epoch 523 is 1.2795226573944092 sec
# Time for epoch 524 is 1.2602474689483643 sec
# Time for epoch 525 is 1.2644438743591309 sec
# Time for epoch 526 is 1.2775440216064453 sec
# Time for epoch 527 is 1.3879270553588867 sec
# Time for epoch 528 is 1.4175169467926025 sec
# Time for epoch 529 is 1.5079896450042725 sec
# Time for epoch 530 is 1.2744855880737305 sec
# Time for epoch 531 is 1.2635478973388672 sec
# Time for epoch 532 is 1.2682616710662842 sec
# Time for epoch 533 is 1.2584505081176758 sec
# Time for epoch 534 is 1.2584285736083984 sec
# Time for epoch 535 is 1.2749974727630615 sec
# Time for epoch 536 is 1.269934892654419 sec
# Time for epoch 537 is 1.45802903175354 sec
# Time for epoch 538 is 1.4927690029144287 sec
# Time for epoch 539 is 1.2886269092559814 sec
# Time for epoch 540 is 1.2672460079193115 sec
# Time for epoch 541 is 1.2724013328552246 sec
# Time for epoch 542 is 1.2763736248016357 sec
# Time for epoch 543 is 1.272789478302002 sec
# Time for epoch 544 is 1.2614059448242188 sec
# Time for epoch 545 is 1.286550760269165 sec
# Time for epoch 546 is 1.4040851593017578 sec
# Time for epoch 547 is 1.4618937969207764 sec
# Time for epoch 548 is 1.3929290771484375 sec
# Time for epoch 549 is 1.2879924774169922 sec
# Time for epoch 550 is 1.254723310470581 sec
# Time for epoch 551 is 1.2715559005737305 sec
# Time for epoch 552 is 1.2846553325653076 sec
# Time for epoch 553 is 1.2599408626556396 sec
# Time for epoch 554 is 1.2752304077148438 sec
# Time for epoch 555 is 1.2547273635864258 sec
# Time for epoch 556 is 1.4447340965270996 sec
# Time for epoch 557 is 1.4374196529388428 sec
# Time for epoch 558 is 1.2925825119018555 sec
# Time for epoch 559 is 1.2756025791168213 sec
# Time for epoch 560 is 1.2897613048553467 sec
# Time for epoch 561 is 1.2686290740966797 sec
# Time for epoch 562 is 1.259437084197998 sec
# Time for epoch 563 is 1.2633183002471924 sec
# Time for epoch 564 is 1.3144595623016357 sec
# Time for epoch 565 is 1.4029102325439453 sec
# Time for epoch 566 is 1.4540190696716309 sec
# Time for epoch 567 is 1.4292690753936768 sec
# Time for epoch 568 is 1.2865424156188965 sec
# Time for epoch 569 is 1.26253080368042 sec
# Time for epoch 570 is 1.2812995910644531 sec
# Time for epoch 571 is 1.2796719074249268 sec
# Time for epoch 572 is 1.2559380531311035 sec
# Time for epoch 573 is 1.2574875354766846 sec
# Time for epoch 574 is 1.2563819885253906 sec
# Time for epoch 575 is 1.441939115524292 sec
# Time for epoch 576 is 1.4540038108825684 sec
# Time for epoch 577 is 1.2853467464447021 sec
# Time for epoch 578 is 1.26466965675354 sec
# Time for epoch 579 is 1.3069484233856201 sec
# Time for epoch 580 is 1.2756314277648926 sec
# Time for epoch 581 is 1.2750353813171387 sec
# Time for epoch 582 is 1.2704415321350098 sec
# Time for epoch 583 is 1.2817747592926025 sec
# Time for epoch 584 is 1.4073517322540283 sec
# Time for epoch 585 is 1.4525916576385498 sec
# Time for epoch 586 is 1.3645401000976562 sec
# Time for epoch 587 is 1.2729997634887695 sec
# Time for epoch 588 is 7.316452503204346 sec
# Time for epoch 589 is 1.497936487197876 sec
# Time for epoch 590 is 1.4029443264007568 sec
# Time for epoch 591 is 1.4223449230194092 sec
# Time for epoch 592 is 1.2628130912780762 sec
# Time for epoch 593 is 1.2687852382659912 sec
# Time for epoch 594 is 1.2719199657440186 sec
# Time for epoch 595 is 1.2585151195526123 sec
# Time for epoch 596 is 1.2607266902923584 sec
# Time for epoch 597 is 1.2788491249084473 sec
# Time for epoch 598 is 1.2709996700286865 sec
# Time for epoch 599 is 1.4477531909942627 sec
# Time for epoch 600 is 1.4791889190673828 sec
# Time for epoch 601 is 1.2747879028320312 sec
# Time for epoch 602 is 1.275007724761963 sec
# Time for epoch 603 is 1.2759816646575928 sec
# Time for epoch 604 is 1.2637975215911865 sec
# Time for epoch 605 is 1.2914681434631348 sec
# Time for epoch 606 is 1.2883644104003906 sec
# Time for epoch 607 is 1.2836246490478516 sec
# Time for epoch 608 is 1.4519336223602295 sec
# Time for epoch 609 is 1.413731575012207 sec
# Time for epoch 610 is 1.475475549697876 sec
# Time for epoch 611 is 1.2678472995758057 sec
# Time for epoch 612 is 1.2650790214538574 sec
# Time for epoch 613 is 1.2819812297821045 sec
# Time for epoch 614 is 1.2635722160339355 sec
# Time for epoch 615 is 1.2757751941680908 sec
# Time for epoch 616 is 1.297518253326416 sec
# Time for epoch 617 is 1.2638208866119385 sec
# Time for epoch 618 is 1.4575610160827637 sec
# Time for epoch 619 is 1.4572770595550537 sec
# Time for epoch 620 is 1.3044350147247314 sec
# Time for epoch 621 is 1.2950119972229004 sec
# Time for epoch 622 is 1.2887213230133057 sec
# Time for epoch 623 is 1.270064353942871 sec
# Time for epoch 624 is 1.281325340270996 sec
# Time for epoch 625 is 1.2663109302520752 sec
# Time for epoch 626 is 1.2661099433898926 sec
# Time for epoch 627 is 1.4299654960632324 sec
# Time for epoch 628 is 1.4349339008331299 sec
# Time for epoch 629 is 1.4778904914855957 sec
# Time for epoch 630 is 1.2682781219482422 sec
# Time for epoch 631 is 1.2843096256256104 sec
# Time for epoch 632 is 1.2682857513427734 sec
# Time for epoch 633 is 1.2617428302764893 sec
# Time for epoch 634 is 1.2821249961853027 sec
# Time for epoch 635 is 1.2626452445983887 sec
# Time for epoch 636 is 1.2634038925170898 sec
# Time for epoch 637 is 1.4562358856201172 sec
# Time for epoch 638 is 1.4701862335205078 sec
# Time for epoch 639 is 1.2727489471435547 sec
# Time for epoch 640 is 1.251049280166626 sec
# Time for epoch 641 is 1.2839810848236084 sec
# Time for epoch 642 is 1.267211675643921 sec
# Time for epoch 643 is 1.2671492099761963 sec
# Time for epoch 644 is 1.2775688171386719 sec
# Time for epoch 645 is 1.2469120025634766 sec
# Time for epoch 646 is 1.3384554386138916 sec
# Time for epoch 647 is 1.4044287204742432 sec
# Time for epoch 648 is 1.5543959140777588 sec
# Time for epoch 649 is 1.2719981670379639 sec
# Time for epoch 650 is 1.2630150318145752 sec
# Time for epoch 651 is 1.2688310146331787 sec
# Time for epoch 652 is 1.2938315868377686 sec
# Time for epoch 653 is 1.2878131866455078 sec
# Time for epoch 654 is 1.267230749130249 sec
# Time for epoch 655 is 1.2749559879302979 sec
# Time for epoch 656 is 1.416773796081543 sec
# Time for epoch 657 is 1.4830708503723145 sec
# Time for epoch 658 is 1.268019676208496 sec
