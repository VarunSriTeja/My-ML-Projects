# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.regularizers import L2

# %%
ds_train = tf.keras.preprocessing.image_dataset_from_directory(
    '/content/drive/MyDrive/homer_bart',
    labels='inferred',
    label_mode='int',
    color_mode='rgb',
    batch_size=4,
    image_size=(64, 64),
    shuffle=True,
    seed=123,


)
train_size = int(0.9 * len(ds_train))
test_size = len(ds_train) - train_size

ds_train_final = ds_train.take(train_size)
ds_test = ds_train.skip(train_size).take(test_size)
# Out:
# Found 269 files belonging to 2 classes.

# %%
model = Sequential([

    Flatten(input_shape=(64, 64, 3)),
    Dense(256, activation='relu',kernel_regularizer=L2(0.001)),
    Dense(128, activation='relu',kernel_regularizer=L2(0.001)),
    Dense(64, activation='relu',kernel_regularizer=L2(0.001)),
    Dense(2, activation='sigmoid')
])

# %%
model.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(),
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    metrics=['accuracy'],
)

# %%
history = model.fit(ds_train_final, epochs=10)
test_loss, test_acc = model.evaluate(ds_test)
print(f'Test accuracy: {test_acc}')
# Out:
# Epoch 1/10
# 61/61 [==============================] - 50s 622ms/step - loss: 491.7064 - accuracy: 0.5492
# Epoch 2/10
# 61/61 [==============================] - 3s 54ms/step - loss: 192.9610 - accuracy: 0.6639
# Epoch 3/10
# 61/61 [==============================] - 4s 69ms/step - loss: 66.3699 - accuracy: 0.7254
# Epoch 4/10
# 61/61 [==============================] - 3s 50ms/step - loss: 35.6631 - accuracy: 0.7787
# Epoch 5/10
# 61/61 [==============================] - 3s 51ms/step - loss: 58.1529 - accuracy: 0.7336
# Epoch 6/10
# 61/61 [==============================] - 4s 67ms/step - loss: 33.0467 - accuracy: 0.7623
# Epoch 7/10
# 61/61 [==============================] - 3s 49ms/step - loss: 54.6772 - accuracy: 0.6885
# Epoch 8/10
# 61/61 [==============================] - 3s 49ms/step - loss: 22.5974 - accuracy: 0.7828
# Epoch 9/10
# 61/61 [==============================] - 4s 68ms/step - loss: 8.1309 - accuracy: 0.8484
# Epoch 10/10
# ...
